# %%
import cv2
from os import listdir
from os.path import isfile, join
import os

# %%
vid_path='D:\Documents\AAAAJupyterNotebook\cs636\morevi\sep'
vid_names = [f for f in listdir(vid_path) if isfile(join(vid_path, f))]

# %%
tname=vid_names[0]

# %%
cap = cv2.VideoCapture(join(vid_path, name))

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc, 25.0, (,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,0)

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
vid=cv2.VideoCapture(join(vid_path, name))
ok, frame=vid.read()
if not ok:
    print(name)
fourcc = cv2.VideoWriter_fourcc(*"MJPG")
print(frame.shape)
print((int(frame.shape[0]),int(frame.shape[1]/2),int(frame.shape[2])))
print(frame[:,:int(frame.shape[1]/2)].shape)
outleft=cv2.VideoWriter('left_'+name,fourcc,25,(int(frame.shape[1]/2),int(frame.shape[0])))
outright=cv2.VideoWriter('right_'+name,fourcc,25,(int(frame.shape[1]/2),int(frame.shape[0])))
outleft.write(frame[:,:int(frame.shape[1]/2)])
outright.write(frame[:,int(frame.shape[1]/2):])
while True:
    ok, frame=vid.read()
    if not ok:
        break
    outleft.write(frame[:,:int(frame.shape[1]/2),:])
    outright.write(frame[:,int(frame.shape[1]/2):,:])
vid.release()
outleft.release()
outright.release()
# Out:
# (720, 1280, 3)
# (720, 640, 3)
# (720, 640, 3)
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...

# %%
for name in vid_names:
    vid=cv2.VideoCapture(join(vid_path, name))
    ok, frame=vid.read()
    if not ok:
        print(name)
        continue
    fourcc = cv2.VideoWriter_fourcc(*"MJPG")
    outleft=cv2.VideoWriter('left_'+name,fourcc,25,(int(frame.shape[1]/2),int(frame.shape[0])))
    outright=cv2.VideoWriter('right_'+name,fourcc,25,(int(frame.shape[1]/2),int(frame.shape[0])))
    outleft.write(frame[:,:int(frame.shape[1]/2)])
    outright.write(frame[:,int(frame.shape[1]/2):])
    while True:
        ok, frame=vid.read()
        if not ok:
            break
        outleft.write(frame[:,:int(frame.shape[1]/2)])
        outright.write(frame[:,int(frame.shape[1]/2):])
    vid.release()
    outleft.release()
    outright.release()

# %%
D:\FFOutput\notpunchRENAME

# %%
fpath=r'D:\FFOutput\testclipped'
fs = [f for f in listdir(fpath) if isfile(join(fpath, f))]
for f in fs:
    os.rename(join(fpath, f), join(fpath, f.replace(' ','').replace('(','').replace(')','')))

# %%
fs[0].replace(' ','')
# Out:
# 'AthleticMaleStandardWalk-Realtime.AnimationReferenceBodyMechanics.mp4'

# %%
join(vid_path, f)
# Out:
# 'D:\\Documents\\AAAAJupyterNotebook\\cs636\\morevi\\sep\\Young Adult Female walk dazed - Realtime. Animation Reference Body Mechanics.mp4'

# %%
join(vid_path, f.replace(' ',''))
# Out:
# 'D:\\Documents\\AAAAJupyterNotebook\\cs636\\morevi\\sep\\YoungAdultFemalewalkdazed-Realtime.AnimationReferenceBodyMechanics.mp4'
